# %% [markdown]
# # Examen — Unidad 1
#
# Notebook de trabajo del examen. Datos de **Our World in Data**.

# %% [markdown]
# ## 1. Importación de librerías

# %%
import pandas as pd
import numpy as np
import requests
