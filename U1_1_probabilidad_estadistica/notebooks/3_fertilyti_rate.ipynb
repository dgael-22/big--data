# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
# Fetch the data.
df = pd.read_csv("https://ourworldindata.org/grapher/children-born-per-woman.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# Fetch the metadata
metadata = requests.get("https://ourworldindata.org/grapher/children-born-per-woman.metadata.json?v=1&csvType=full&useColumnShortNames=true").json()

# %%
df.shape
# Out:
# (19402, 4)

# %%
df.columns.tolist()
# Out:
# ['entity', 'code', 'year', 'fertility_rate_hist']

# %%
mexico = df[df['entity'] == 'Mexico']
japan = df[df['entity'] == 'Japan']

# %%
mexico.shape
# Out:
# (74, 4)

# %%
japan.shape
# Out:
# (77, 4)

# %%
anios_mexico = mexico['year'].to_numpy()

# %%
mexico.head()
# Out:
#        entity code  year  mean_age_childbearing_hist
# 10903  Mexico  MEX  1950                      29.025
# 10904  Mexico  MEX  1951                      29.022
# 10905  Mexico  MEX  1952                      29.019
# 10906  Mexico  MEX  1953                      29.017
# 10907  Mexico  MEX  1954                      29.014

# %%
tasa_mexico= mexico['fertility_rate_hist'].to_numpy()

# %%
anios_japon = japan['year'].to_numpy()
tasa_japon= japan['fertility_rate_hist'].to_numpy()

# %%
type(mexico)
# Out:
# pandas.DataFrame

# %%
type(mexico['year'])
# Out:
# pandas.Series

# %%
type

# %%
promedio_mexico = np.mean(tasa_mexico)
maximo_mexico = np.max(tasa_mexico)

minimo_mexico = np.min(tasa_mexico)
desviacion_mexico = np.std(tasa_mexico)

# %%
plt.figure(figsize=(10, 5))

# %%
plt.figure(figsize=(10, 5))
plt.plot(anios_mexico,
        tasa_mexico,
        label='Mexico' 
)

plt.title('Tasa de fertilidad en México')
plt.xlabel('Año')
plt.ylabel('Nacimientos por cada 1k habitantes')
plt.grid(True)
plt.legend()

# %%
plt.figure(figsize=(10, 5))
plt.plot(anios_japon,
        tasa_japon,
        label='Japón' 
)

plt.title('Tasa de fertilidad en Japón')
plt.xlabel('Año')
plt.ylabel('Nacimientos por cada 1k habitantes')
plt.grid(True)
plt.legend()

# %%
plt.Figure(figsize=(10, 5))

plt.plot(anios_mexico,
        tasa_mexico,
        label='Mexico'
)

plt.plot(anios_japon,
        tasa_japon,
        label='Japón'
)
plt.title('Tasa de fertilidad')
plt.xlabel('Año')
plt.ylabel('Nacimientos por cada 1k habitantes')
plt.grid(True)
plt.legend()

# %%
##filtro por indesaccion boleana 
mascara_conciencia_anios = anios_japon >=  anios_mexico.min()

# %%
mascara_conciencia_anios
# Out:
# array([False, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
mascara_conciencia_anios.shape
# Out:
# (77,)

# %%
anios_japon = anios_japon[mascara_conciencia_anios]

# %%
tasa_japon = tasa_japon[mascara_conciencia_anios]

# %%
anios_japon.shape
# Out:
# (74,)

# %%
anios_mexico.shape
# Out:
# (74,)

# %%
diferencia = tasa_mexico - tasa_japon

# %%
tasa_japon2 = tasa_japon[mascara_conciencia_anios]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 tasa_japon2 = tasa_japon[mascara_conciencia_anios]
#
# IndexError: boolean index did not match indexed array along axis 0; size of axis is 74 but size of corresponding boolean axis is 77

# %%
diferencia = tasa_mexico - tasa_japon

# %%
plt.figure(figsize=(10, 5))
plt.plot(anios_mexico, tasa_mexico, label='Mexico', color='blue')
plt.plot(anios_japon, tasa_japon, label='Japan', color='red')  
plt.plot(anios_mexico, diferencia, label='Diferencia', color='green')
plt.xlabel('Año')
plt.ylabel('Tasa de Fertilidad')
plt.title('Comparación de Tasa de Fertilidad')
plt.legend()
plt.show()

# %%
array = np.array([1, 2, 3, 4, 5])

# %%
arrat_suma = array + 10

# %%
array_multiplicacion = array * 2

# %%
array_promedio = np.mean(array)

# %%
anios_comunes = np.intersect1d(
    anios_mexico, 
    anios_japon
    )

# %%
len(anios_comunes)
# Out:
# 71

# %%
mexico_anios_comunes = mexico[mexico['year'].isin(anios_comunes)]
japan_anios_comunes = japan[japan['year'].isin(anios_comunes)]

# %%
mexico_tasa_comunes = mexico_anios_comunes['fertility_rate_hist'].isin(anios_comunes)
japan_tasa_comunes = japan_anios_comunes['fertility_rate_hist'].isin(anios_comunes)

# %%
mex_anios_comunes = mexico_anios_comunes['year'].to_numpy()
jpn_anios_comunes = japan_anios_comunes['year'].to_numpy()

mex_tasa_comunes = mexico_anios_comunes['fertility_rate_hist'].to_numpy()
jpn_tasa_comunes = japan_anios_comunes['fertility_rate_hist'].to_numpy()

# %%
print(anios_comunes[30])
# Out:
# 1980

# %%
anios_japon = np.delete(anios_japon, [30, 42, 48])

# %%
mex_anios_comunes=mexico_anios_comunes.to_numpy()
jpn_anios_comunes=japan_anios_comunes.to_numpy()

mex_tasa_comunes = mexico_anios_comunes['fertility_rate_hist'].to_numpy()
jpn_tasa_comunes = japan_anios_comunes['fertility_rate_hist'].to_numpy()

# %%
plt.figure(figsize=(10, 5))
plt.plot(mex_anios_comunes, mex_tasa_comunes, label='Mexico', color='blue')
plt.plot(jpn_anios_comunes, jpn_tasa_comunes, label='Japan', color='red')
plt.xlabel('Año')
plt.ylabel('Tasa de Fertilidad')
plt.title('Comparación de Tasa de Fertilidad')
plt.legend()
plt.show()

# %%
#craemos una nueva data 

comparacion_mexico_japon = pd.merge(
    mexico_anios_comunes, 
    japan_anios_comunes, 
    on='year', 
    suffixes=('_mexico', '_japon')
    )

# %%
comparacion_mexico_japon.head()
# Out:
#   entity_mexico code_mexico  year  fertility_rate_hist_mexico entity_japon  \
# 0        Mexico         MEX  1950                       6.709        Japan
# 1        Mexico         MEX  1951                       6.727        Japan
# 2        Mexico         MEX  1952                       6.731        Japan
# 3        Mexico         MEX  1953                       6.734        Japan
# 4        Mexico         MEX  1954                       6.745        Japan
#
#   code_japon  fertility_rate_hist_japon
# 0        JPN                      3.615
# 1        JPN                      3.225
# 2        JPN                      2.947
# 3        JPN                      2.673
# 4        JPN                      2.468

# %%
comparacion_mexico_japon ["diferencia"] = (
    comparacion_mexico_japon ["fertility_rate_hist_mexico"] 
    - comparacion_mexico_japon ["fertility_rate_hist_japon"]
)

# %%
comparacion_mexico_japon.head(3
)
# Out:
#   entity_mexico code_mexico  year  fertility_rate_hist_mexico entity_japon  \
# 0        Mexico         MEX  1950                       6.709        Japan
# 1        Mexico         MEX  1951                       6.727        Japan
# 2        Mexico         MEX  1952                       6.731        Japan
#
#   code_japon  fertility_rate_hist_japon  diferencia
# 0        JPN                      3.615       3.094
# 1        JPN                      3.225       3.502
# 2        JPN                      2.947       3.784

# %%
plt.figure(figsize=(10, 5))

comparacion_mexico_japon.plot(x='year', y=['fertility_rate_hist_mexico', 'fertility_rate_hist_japon', 'diferencia'], kind='line')

plt.xlabel('Año')
plt.ylabel('Tasa de Fertilidad')
plt.title('Comparación de Tasa de Fertilidad entre México y Japón')
plt.legend()
plt.show()
